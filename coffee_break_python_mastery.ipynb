# %% [markdown]
# <a href="https://colab.research.google.com/github/WilsonPsychedelic/cli_utils/blob/main/coffee_break_python_mastery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ☕ Coffee Break Python – Mastery Workout
# ### 99 Tricky Python Puzzles
# *Rieger, Chan, Mayer – Finxter*
#
# ---
# For each puzzle: **predict the output** before running the cell!

# %% [markdown]
# ---
# ## Chapter 2 — Elo 1300–1400 · Learner

# %% [markdown]
# ### 2.1 — Basic For Loop
# *What's the output of this code snippet?*

# %%
# Elo 1348
n, count = 5, 0
print(f"n: {n}, count: {count}")

for _ in range(n): # 0 -> 4
    print(f"_ : {_}")
    n -= 1 # n = n - 1

    count += 1 # count = count + 1
    print(f"n: {n}, count: {count}")
    print(count)

print(f"n: {n}, count: {count}")
print(_)
# Out:
# n: 5, count: 0
# _ : 0
# n: 4, count: 1
# 1
# _ : 1
# n: 3, count: 2
# 2
# _ : 2
# n: 2, count: 3
# 3
# _ : 3
# n: 1, count: 4
# 4
# _ : 4
# n: 0, count: 5
# 5
# n: 0, count: 5
# 4

# %% [markdown]
# ### 2.2 — Variable Scope III
# *What's the output of this code snippet?*

# %%
# Elo 1367
def swap(a, b):
    return b, a
a, b = 1, 2
a, b = swap(a, b)
print(a - b)
# Out:
# 1

# %% [markdown]
# ---
# ## Chapter 3 — Elo 1400–1500 · Experienced Learner

# %% [markdown]
# ### 3.1 — Boolean Conversion
# *What's the output of this code snippet?*

# %%
# Elo 1487
x = 0
if False or [True] or (False):
    x += 1
    print(x)
# Out:
# 1

# %%
[] and True
# Out:
# []

# %% [markdown]
# ### 3.2 — Tuple Constructor
# *What's the output of this code snippet?*

# %%
# Elo 1489
s = 'abc'
for _ in range(10):
    s = tuple(s)
    print(len(s))
# Out:
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3

# %%
S = "abc"
print(list(S))
print(tuple(S))
print(set(S))
# Out:
# ['a', 'b', 'c']
# ('a', 'b', 'c')
# {'a', 'c', 'b'}

# %%
len(("abc"))
# Out:
# 3

# %%
("abc")
# Out:
# 'abc'

# %% [markdown]
# ### 3.3 — Popping List Elements
# *What's the output of this code snippet?*

# %%
# Elo 1499
t = [1, 2, 3, 4]
x = t.pop() > t.pop() > t.pop()
print(x)
# x = 4 > 3 > 2
t.append(x)
print(t)
print(len(t))
# Out:
# True
# [1, True]
# 2

# %%
4 > 3 > 2
# Out:
# True

# %% [markdown]
# ---
# ## Chapter 4 — Elo 1500–1600 · Intermediate

# %% [markdown]
# ### 4.1 — Extending Lists
# *What's the output of this code snippet?*

# %%
# @title
# Elo 1517
t = [1, 2, 3, 4]
x = (t.pop() < t.pop()), t.pop()
t.extend(x)
print(t)
print(len(t))
# Out:
# [1, False, 2]
# 3

# %% [markdown]
# ### 4.2 — list.extend() vs. list.append()
# *What's the output of this code snippet?*

# %%
# @title
# Elo 1539
t = [0, 1, 2]
t.extend([])
t.append([])
print(len(t))
print(t)
# Out:
# 4
# [0, 1, 2, []]

# %% [markdown]
# ### 4.3 — List Objects
# *What's the output of this code snippet?*

# %%
# @title
# Elo 1545
t = [0, 1, [2], 3]
y = t[2]
y.append(20)
print(t[2])

# %% [markdown]
# ### 4.4 — Python Basic Set Operations
# *What's the output of this code snippet?*

# %%
# Elo 1587
a = [1, 1, 1, 2, 3, 3]
b = [0, 0, 0, 1, 3, 3]
print(set(a) >= set(b))

# %% [markdown]
# ### 4.5 — Length Arithmetik
# *What's the output of this code snippet?*

# %%
# Elo 1587
s = '-5\\3'
print(len(s))

# %% [markdown]
# ### 4.6 — Print Arguments
# *What's the output of this code snippet?*

# %%
# Elo 1589
t = 'abc'
d = {'sep': '-', 'end': '?'}
print(*t, **d)

# %% [markdown]
# ### 4.7 — Dictionary Keys
# *What's the output of this code snippet?*

# %%
# Elo 1598
x = 10
d = {x:0, 11:1}
x = 11
print(d[x])

# %% [markdown]
# ---
# ## Chapter 5 — Elo 1600–1700 · Experienced Intermediate

# %% [markdown]
# ### 5.1 — String Find
# *What's the output of this code snippet?*

# %%
# Elo 1602
s = 'bed and breakfast'
r = s.find('bed') == False
print(r)

# %% [markdown]
# ### 5.2 — Slicing
# *What's the output of this code snippet?*

# %%
# Elo 1639
s = 'smart'
print(s[:-100:-2])

# %% [markdown]
# ### 5.3 — List Arithmetic I
# *What's the output of this code snippet?*

# %%
# Elo 1665
tup = 0, 1, 2
lst = [tup]
lst.append(3)
lst.pop(0)
print(len(lst))

# %% [markdown]
# ### 5.4 — List Arithmetic II
# *What's the output of this code snippet?*

# %%
# Elo 1666
tup = 0, 1, 2
lst = list(tup)
lst.append(3)
lst.pop(0)
print(len(lst))

# %% [markdown]
# ### 5.5 — Variable Scope II
# *What's the output of this code snippet?*

# %%
# Elo 1671
def swap():
    b, a = a, b
    a, b = 1, 2
    swap()
    print(a - b)

# %% [markdown]
# ### 5.6 — String Find
# *What's the output of this code snippet?*

# %%
# Elo 1689
s = 'apple'
print(s.find('p') + s.find('f') + s.find(''))

# %% [markdown]
# ### 5.7 — Zip Heterogeneous Lists
# *What's the output of this code snippet?*

# %%
# Elo 1699
p = ['abc']
q = ['a', 'b', 'c']
zipped = list(zip(p, q))
print(len(zipped))

# %% [markdown]
# ---
# ## Chapter 6 — Elo 1700–1800 · Professional

# %% [markdown]
# ### 6.1 — Boolean Integer Relationship
# *What's the output of this code snippet?*

# %%
# Elo 1721
num = 0
for i in range(5, 0, -1):
    num += i > num
    print(num)

# %% [markdown]
# ### 6.2 — Slice Assignment Basics
# *What's the output of this code snippet?*

# %%
# Elo 1749
t = [1, 2, 3]
t[-1:] = [4]
t[-1] = [5]
print(len(t))

# %% [markdown]
# ### 6.3 — List Multiplication
# *What's the output of this code snippet?*

# %%
# Elo 1755
t = [0, 1, 2]
t2 = t * 1
t[0] = 100
print(t2)

# %% [markdown]
# ### 6.4 — Integers in Memory
# *What's the output of this code snippet?*

# %%
# Elo 1766
x = 10
d = {'Peter': x, 'Tom': x, 'Mary': x}
x = 11
print(d['Peter'])

# %% [markdown]
# ### 6.5 — Slice Assignment
# *What's the output of this code snippet?*

# %%
# Elo 1767
t = [1, 2, 3, 4]
t[2::-2] = [10, 30]
print(t[0])

# %% [markdown]
# ### 6.6 — Maximum With Key
# *What's the output of this code snippet?*

# %%
# Elo 1771
t = [-2, 9, 0, -8]
key = lambda x: -abs(x)
print(max(t, key=key))

# %% [markdown]
# ### 6.7 — Maximum With Key
# *What's the output of this code snippet?*

# %%
# Elo 1777
t = [0, 1, 2, 3]
print(max(t, key=lambda x: x%2))

# %% [markdown]
# ### 6.8 — Variable Scoping Lists
# *What's the output of this code snippet?*

# %%
# Elo 1777
t = [0]
def f():
    t.append(10)
    t = [1]
    f()
    print(t)

# %% [markdown]
# ### 6.9 — Dictionary Comprehension
# *What's the output of this code snippet?*

# %%
# Elo 1787
a, b, c = dict((i, i*2) for i in range(3))
print(a)

# %% [markdown]
# ### 6.10 — Minimum with Key
# *What's the output of this code snippet?*

# %%
# Elo 1787
strings = ['flies', 'zzz', 'mammal']
first = min(strings, key=lambda x: len(set(x)))
print(first)

# %% [markdown]
# ### 6.11 — Slice Assignment
# *What's the output of this code snippet?*

# %%
# Elo 1788
t = [-1, -2, -3, -4]
t[t[-1]: t[-4]] = t[-1], t[-4]
print(t[0])

# %% [markdown]
# ### 6.12 — Keyword Arguments
# *What's the output of this code snippet?*

# %%
# Elo 1789
def f(x, y, z=0):
    if z:
        return min(y)
    else:
        return max(y)

args = {'y': (2, 3, 4), 'z': 5}
print(f(x=1, **args))

# %% [markdown]
# ### 6.13 — Assignment Confusion
# *What's the output of this code snippet?*

# %%
# Elo 1797
class A:
    z = 10
    def __init__(self, x, y=1):
        self.x = x
        self.y = y
        a = A(3)
        z = a.z
        A.z = 8
        print(z)

# %% [markdown]
# ### 6.14 — Slice Assignment
# *What's the output of this code snippet?*

# %%
# Elo 1798
t = [0, 1, 2]
t[2:] += [t[0]]
print(t)

# %% [markdown]
# ### 6.15 — Unpacking Strings
# *What's the output of this code snippet?*

# %%
# Elo 1799
x, *y = '234'
print(x + min(y))

# %% [markdown]
# ---
# ## Chapter 7 — Elo 1800–1900 · Expert

# %% [markdown]
# ### 7.1 — While ... Else Loop
# *What's the output of this code snippet?*

# %%
# Elo 1800
t = [1, 0, 3, 8]
while t.pop():
    if t.pop():
        break
    else:
        t.pop()
print(t)

# %% [markdown]
# ### 7.2 — Enumerating Dictionaries
# *What's the output of this code snippet?*

# %%
# Elo 1802
d = {0: 'Peter', 1: 'Tom', 2: 'Mary'}
for i, x in enumerate(d):
    if i % 2:
        print(x)
        break

# %% [markdown]
# ### 7.3 — Negative Slice Indices
# *What's the output of this code snippet?*

# %%
# Elo 1803
t = [1, 2, 3]
print(t[-1:-2])

# %% [markdown]
# ### 7.4 — Iterable Unpacking
# *What's the output of this code snippet?*

# %%
# Elo 1807
x, y = '12'
y, z = '34'
print(x + y + z)

# %% [markdown]
# ### 7.5 — Default Arguments in Constructor
# *What's the output of this code snippet?*

# %%
# Elo 1849
t = [0]
def f(t=t):
    t.append(10)
    print(t)
t = [1]
f()

# %% [markdown]
# ### 7.6 — List Arithmetic III
# *What's the output of this code snippet?*

# %%
# Elo 1845
tup = [0], [1], [2]
lst = list(tup)
lst[0][0] = 10
print(tup[0])

# %% [markdown]
# ### 7.7 — Default Function Arguments
# *What's the output of this code snippet?*

# %%
# Elo 1849
t = [0]
def f(t=t):
    t.append(10)
    print(t)
    t = [1]
    f()

# %% [markdown]
# ### 7.8 — Class Variables and Inheritance
# *What's the output of this code snippet?*

# %%
# Elo 1856
class A:
    num = 1
class B(A):
    pass
class C(B):
    pass
A.num, B.num = 2, 3
print(C.num)

# %% [markdown]
# ### 7.9 — Integer and String Conversions
# *What's the output of this code snippet?*

# %%
# Elo 1867
a = str(10) + str(20) == str(10 + 20)
b = str(10) + str(20) == str(20) + str(10)
c = str(10) * 20 == 20 * str(10)
print(a + b + c)

# %% [markdown]
# ### 7.10 — Finding Substrings
# *What's the output of this code snippet?*

# %%
# Elo 1876
word = 'finxter'
letters = 'fix'
selected = [w for w in word if
letters.find(w)]
print(len(selected))

# %% [markdown]
# ### 7.11 — Integer and Float Conversions
# *What's the output of this code snippet?*

# %%
# Elo 1877
a = int(2.6) + int(-3.6) == int(2.6 + -3.6)
b = int('2') + int('3') == int('2' + '3')
c = int(-3.6) == -int(3.6)
print(a + b + c)

# %% [markdown]
# ### 7.12 — List Operations
# *What's the output of this code snippet?*

# %%
# Elo 1878
t = [1, 3, 5, 1, 3, 5]
x = t.pop(3) + t.index(5) + t.count(1)
print(x)

# %% [markdown]
# ### 7.13 — Variable Scope I
# *What's the output of this code snippet?*

# %%
# Elo 1879
def swap(a, b):
    b, a = a, b
    a, b = 1, 2
    swap(a, b)
    print(a - b)

# %% [markdown]
# ### 7.14 — Arbitrary Arguments
# *What's the output of this code snippet?*

# %%
# Elo 1881
def f(x, *y, z=0):
    if z:
        return min(y)
    else:
        return max(y)

print(f(1, 2, 3, 4, 5))

# %% [markdown]
# ### 7.15 — Dictionary Unpacking and Assignment
# *What's the output of this code snippet?*

# %%
# Elo 1884
capitals = {'usa': 'washington',
'uk': 'manchester',
'italy': 'rome',
'china': 'beijing'}
x, *y, z = {**capitals, 'uk': 'london'}
print(y)

# %% [markdown]
# ### 7.16 — List Object
# *What's the output of this code snippet?*

# %%
# Elo 1886
t = [0]
s1 = s2 = t
s1 = s1 + [1]
s2 += [1]
print(t)

# %% [markdown]
# ### 7.17 — Recursion
# *What's the output of this code snippet?*

# %%
# Elo 1887
def f(x):
    if x % 5 == 0:
        return x
    else:
        return 1 + f(x - 1)

n = f(f(9))
print(n)

# %% [markdown]
# ### 7.18 — Ternary Operator
# *What's the output of this code snippet?*

# %%
# Elo 1889
translation = {'please': 'bitte', 'thank you': 'danke', 'good': 'gut'}
for word in translation:
    word = word.capitalize() if len(word.split()) > 1 else word.upper()
print(list(translation)[1])

# %% [markdown]
# ### 7.19 — Memory Allocation
# *What's the output of this code snippet?*

# %%
# Elo 1899
x = [0]
t = [x for _ in range(3)]
t[0][0] = 100
print(t[2])

# %% [markdown]
# ### 7.20 — Scope of Instance Attributes
# *What's the output of this code snippet?*

# %%
# Elo 1899
class A:
    x = [1, 2, 3]
    def __init__(self, x=x):
        self.x = x
    def update(self):
        self.x = self.x * 2
        x = ['head', 'shoulder']
        a = A()
        a.update()
        print(A.x)

# %% [markdown]
# ---
# ## Chapter 8 — Elo 1900–2000 · Authority

# %% [markdown]
# ### 8.1 — Dictionary Conditional Insert
# *What's the output of this code snippet?*

# %%
# Elo 1900
d = {0: 'Peter', 1: 'Tom', 2: 'Mary'}
x = d.setdefault(2, 'John')
print(x)

# %% [markdown]
# ### 8.2 — Dictionary Initialization
# *What's the output of this code snippet?*

# %%
# Elo 1900
d = {bool(-1): {0},
True : {0, 1},
1 : {0, 1, 2},
(2,) : {0, 1, 2, 3}}
print(len(d))

# %% [markdown]
# ### 8.3 — List Comprehension Arithmetic
# *What's the output of this code snippet?*

# %%
# Elo 1901
class A:
    x = 'pandas'
    t = [A() for _ in range(10)]
    t[0].x = 'numpy'
    t[1].x = 'sklearn'
    print(t[2].x)

# %% [markdown]
# ### 8.4 — Overriding
# *What's the output of this code snippet?*

# %%
# Elo 1901
class A:
    def func(self):
        return self.run()
    def run(self):
        return 1
class B(A):
    def run(self):
        return 2
class C(B):
    def run(self):
        return 3
    c = C()
    print(c.func())

# %% [markdown]
# ### 8.5 — Understanding Iterables I
# *What's the output of this code snippet?*

# %%
# Elo 1902
lst = [0, 1, 2, 3, 4]
for _ in lst:
    lst.pop()
    print(lst)

# %% [markdown]
# ### 8.6 — Overriding 2.0
# *What's the output of this code snippet?*

# %%
# Elo 1906
class A:
    def func(self):
        return self.run()
    def run(self):
        return 1

class B(A):
    def run(self):
        return 2

class C(B):
    def log(self):
        return 3

c = C()
print(c.func())

# %% [markdown]
# ### 8.7 — List Arithmetic (Multiplication)
# *What's the output of this code snippet?*

# %%
# Elo 1908
class A:
    x = 'pandas'
    t = [A()] * 10
    t[0].x = 'numpy'
    t[1].x = 'sklearn'
    print(t[2].x)

# %% [markdown]
# ### 8.8 — Unpacking for Pros
# *What's the output of this code snippet?*

# %%
# Elo 1912
def f(x, *y):
    t = [*x, y]
    return len(t)
x, y, z = [1, 2, 3], [4, 5], [6]
print(f(x, y, z))

# %% [markdown]
# ### 8.9 — Customizing the Minimum
# *What's the output of this code snippet?*

# %%
# Elo 1914
key = lambda x: -max(x)
t = (-1, -3), (-4, 9, -2), (0,)
print(min(min(t, key=key)))

# %% [markdown]
# ### 8.10 — Default Arguments
# *What's the output of this code snippet?*

# %%
# Elo 1919
def f(a, t=[]):
    t.append(a)
    return t
print(f(1))
print(f(2))

# %% [markdown]
# ### 8.11 — Unpacking Reloaded
# *What's the output of this code snippet?*

# %%
# Elo 1929
def f(x, *y):
    t = [*x, *y]
    return len(t)
x, y, z = [1, 2, 3], [4, 5], [6]
print(f(x, y, z))

# %% [markdown]
# ### 8.12 — Class Variables Reloaded
# *What's the output of this code snippet?*

# %%
# Elo 1933
class A:
    members = []
    def __init__(self, name):
        self.name = name
        self.members.append(self)
    def __repr__(self):
        return self.name
    w, x, y, z = A('Mary'), A('John'), A('Lucy'),
    A('David')
    A.members.insert(0, A.members.pop())
    print(A.members[-1])

# %% [markdown]
# ### 8.13 — Swapping Values in Instance Methods
# *What's the output of this code snippet?*

# %%
# Elo 1937
class A:
    x, y = 1, 2
    def swap(self):
        self.x, self.y = self.y, self.x

a = A()
a.swap()
print(A.x, A.y)

# %% [markdown]
# ### 8.14 — Slicing Confusion
# *What's the output of this code snippet?*

# %%
# Elo 1943
t = [0, 1, 2]
t[2:].append(t[0])
print(t)

# %% [markdown]
# ### 8.15 — Short Circuiting
# *What's the output of this code snippet?*

# %%
# Elo 1944
var = True - 3 and 10 and - 1
print(var)

# %% [markdown]
# ### 8.16 — Dictionary Comprehension
# *What's the output of this code snippet?*

# %%
# Elo 1944
translation = {'please': 'bitte',
'thank you': 'danke',
'good': 'gut'}
d = {k.capitalize() if len(k.split()) > 1
else k.upper(): v for k, v
in translation.items()}
print(list(d)[1])

# %% [markdown]
# ### 8.17 — Dictionary Pop
# *What's the output of this code snippet?*

# %%
# Elo 1947
d = {'a':1, 'b':2, 'c':3}
x = d.pop('d', 4) or None
y = d.pop('c', None) or 4
print(x or y)

# %% [markdown]
# ### 8.18 — Class Variable vs Instance Attributes
# *What's the output of this code snippet?*

# %%
# Elo 1951
class A:
    t = [1, 2, 3]
    a1, a2 = A(), A()
    a1.t += [4]
    a2.t = a2.t + [4]
    print(len(A.t))

# %% [markdown]
# ### 8.19 — Dictionary Unpacking
# *What's the output of this code snippet?*

# %%
# Elo 1965
d1 = {'a': 1, 'b': 2}
d2 = {'b': 2, 'c': 3}
def f(a, b, c):
    return max((a, b, c))
print(f(**d1, **d2))

# %% [markdown]
# ### 8.20 — Instance and Attribute
# *What's the output of this code snippet?*

# %%
# Elo 1976
class A:
    x = 1

class B(A):
    pass

cond = isinstance(B(), A) and hasattr(B, 'x')
setattr(B, 'x', 2 if cond else 3)
print(A.x, B.x)

# %% [markdown]
# ### 8.21 — Parallel Assignment
# *What's the output of this code snippet?*

# %%
# Elo 1977
t = [0, 1, 2]
t[::2] = t[::-2] = t[:2]
print(t)

# %% [markdown]
# ### 8.22 — Understanding Iterables II
# *What's the output of this code snippet?*

# %%
# Elo 1982
lst = [0, 1, 2, 3, 4]
for _ in lst:
    lst.pop(0)
    print(lst)

# %% [markdown]
# ### 8.23 — Advanced Mapping
# *What's the output of this code snippet?*

# %%
# Elo 1987
x = 'usa'
y = 'uk'
r = min(map(max, x, y))
print(r)

# %% [markdown]
# ### 8.24 — Tuple Concatenation
# *What's the output of this code snippet?*

# %%
# Elo 1988
x = ((())) + (((),),)
print(len(x))

# %% [markdown]
# ### 8.25 — Class vs Instance Variables
# *What's the output of this code snippet?*

# %%
# Elo 1990
class A:
    x, y = 1, 2
class B:
    x, y = 10, 20
    def __init__(self):
        self.y = B.y
class C(A, B):
    pass
c = C()
print(c.x + c.y)

# %% [markdown]
# ### 8.26 — Default Object Arguments
# *What's the output of this code snippet?*

# %%
# Elo 1991
def f(a, t=[]):
    t.append(a)
    return t
mylist = f(1) + f(2)
print(mylist)

# %% [markdown]
# ### 8.27 — Default Function Arguments and Scoping
# *What's the output of this code snippet?*

# %%
# Elo 1999
t = [0]
def f(t=t):
    t.append(10)
    t = [1]
    f()
    print(t)

# %% [markdown]
# ---
# ## Chapter 9 — Elo 2000–2100 · Master Candidate

# %% [markdown]
# ### 9.1 — String Representation
# *What's the output of this code snippet?*

# %%
# Elo 2001
class Person:
    def __init__(self, name, gender, height):
        self.name = name
        self.gender = gender
        self.height = height
    def __repr__(self):
        return 'Tall ' * (self.height > 165) + self.name

p = Person('Joe', 'Boy', 170)
q = Person('Mary', 'Girl', 160)
print([p, q])

# %% [markdown]
# ### 9.2 — List Operations
# *What's the output of this code snippet?*

# %%
# Elo 2007
t = [2, '32', 2, '252']
t.extend('42')
print(t.count('2'))

# %% [markdown]
# ### 9.3 — Slicing Tuples
# *What's the output of this code snippet?*

# %%
# Elo 2010
t = [(1, 2), (3, 4, 5), (6,)]
x = [k[::-2] for k in t[::-2]]
print(x[1])

# %% [markdown]
# ### 9.4 — Zip
# *What's the output of this code snippet?*

# %%
# Elo 2055
d = {0: 'Peter', 1: 'Tom', 2: 'Mary'}
zipped = list(zip(d))
print(zipped[1])

# %% [markdown]
# ### 9.5 — Zip Iteration
# *What's the output of this code snippet?*

# %%
# Elo 2055
class Person:
    def __init__(self, name, gender, height):
        self.name = name
        self.gender = gender
        self.height = height
    def __str__(self):
        return 'Tall ' * (self.height > 165) + self.name

names = ['Joe', 'Mary', 'Tom', 'Peter']
genders = ['Boy', 'Girl', 'Boy']
height = [170, 165, 163, 160]
children = [Person(name, gender, h)
            for name, gender, h in zip(names, genders, height)]
print(children[-1])

# %% [markdown]
# ### 9.6 — Being Precise
# *What's the output of this code snippet?*

# %%
# Elo 2056
t = [0, 1, [2], 3]
y = t[2:3]
y.append(20)
print(t[2])

# %% [markdown]
# ### 9.7 — Set Default Dicts
# *What's the output of this code snippet?*

# %%
# Elo 2061
class A:
    d = {True: 10}
    def __init__(self, func, *args):
        self.d.setdefault(args[0],
        func(*args))
        A(max, -1, -2, -3)
        A(pow, 1, 3)
        print(sum(A.d.values()))

# %% [markdown]
# ### 9.8 — Sequence Comparison
# *What's the output of this code snippet?*

# %%
# Elo 2076
capitals = {'uk': 'london',
'france': 'paris',
'germany': 'berlin'}
print(list(capitals) >
list(capitals.values()))

# %% [markdown]
# ### 9.9 — Definition of Instance Variables
# *What's the output of this code snippet?*

# %%
# Elo 2076
class A:
    count = 0
    def loop(self, times):
        while self.count < times:
            self.count += 1
            a = A()
            a.loop(5)
            print(A.count)

# %% [markdown]
# ### 9.10 — Name Resolution in Classes
# *What's the output of this code snippet?*

# %%
# Elo 2089
class A:
    var = 1
class B(A):
    pass
class C:
    var = 3
class D(B, C):
    pass
print(D.var)

# %% [markdown]
# ---
# ## Chapter 10 — Elo 2100–2200 · National Master

# %% [markdown]
# ### 10.1 — Overriding 3.0
# *What's the output of this code snippet?*

# %%
# Elo 2109
class A:
    t = [10, 20, 30]
    def __init__(self):
        self.t = self.t.pop()
    def func(self):
        return self.run()
    def run(self):
        return self.t
class B(A):
    pass
class C(B):
    pass
b = B()
c = C()
print(c.func())

# %% [markdown]
# ### 10.2 — Short Circuiting
# *What's the output of this code snippet?*

# %%
# Elo 2122
t = [1, 2, 2, 1]
x = t.pop() < t.pop() < t.pop() < t.pop()
t.append(x)
print(len(t))

# %% [markdown]
# ### 10.3 — Boolean Operator Precedence
# *What's the output of this code snippet?*

# %%
# Elo 2141
print(0 not in [1] is not 0 in [1])

# %% [markdown]
# ---
# ## Chapter 11 — Elo 2200–2300 · Master

# %% [markdown]
# ### 11.1 — Operator Precedence
# *What's the output of this code snippet?*

# %%
# Elo 2209
# NOTE: This puzzle intentionally contains a SyntaxError - that IS the answer!
# Python cannot parse "not a == not b" due to operator precedence ambiguity.
# The interpreter raises: SyntaxError: invalid syntax

a = 10 > 9.0
b = not a
# print(not a == not b)  # SyntaxError: invalid syntax

# Fixed version (as shown in the book):
# print((not a) == (not b))  # False

# %% [markdown]
# ### 11.2 — Custom Sum
# *What's the output of this code snippet?*

# %%
# Elo 2288
class A:
    def __init__(self, x):
        self.x = x
    def __add__(self, other):
        return self.x + other.x
    s = sum(A(n) for n in range(4))
    print(s)

# %% [markdown]
# ### 11.3 — Global and Local Variable Scopes
# *What's the output of this code snippet?*

# %%
# Elo 2299
count = 0
def increment(n):
    count += n
    increment(5//2 ** 2)
    print(count)

# %% [markdown]
# ---
# ## Chapter 12 — Elo 2300+ · International Master+

# %% [markdown]
# ### 12.1 — Mutability of Objects
# *What's the output of this code snippet?*

# %%
# Elo 2345
t1 = True, (), [], None
t2 = True, (), [], None
count = sum(map(lambda x, y: x is y, t1, t2))
print(count)

# %% [markdown]
# ### 12.2 — The Complement Operator
# *What's the output of this code snippet?*

# %%
# Elo 2499
y = ~(~True + ~False)
print(y)
